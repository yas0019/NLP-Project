# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer , WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\YASMINE\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\YASMINE\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\YASMINE\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = "Natural Language Processing enables machine to understand human language."

# %%
import nltk
nltk.download('punkt_tab')
tokens = word_tokenize(text)
tokens
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\YASMINE\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ['Natural',
#  'Language',
#  'Processing',
#  'enables',
#  'machine',
#  'to',
#  'understand',
#  'human',
#  'language',
#  '.']

# %%
stop_words=set (stopwords.words('english'))
filtered_tokens=[word for word in tokens if word.lower() not in stop_words]

# %%
#stemmings
ps=PorterStemmer()
stemmed_tokens=[ps.stem (word) for word in filtered_tokens]

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

# %%
print("Tokens:",tokens)
print("Filtered Tokens:",filtered_tokens)
print("Stemmed Tokens:",stemmed_tokens)
print("Lemmatized Tokens:",lemmatized_tokens)
# Out:
# Tokens: ['Natural', 'Language', 'Processing', 'enables', 'machine', 'to', 'understand', 'human', 'language', '.']
# Filtered Tokens: ['Natural', 'Language', 'Processing', 'enables', 'machine', 'understand', 'human', 'language', '.']
# Stemmed Tokens: ['natur', 'languag', 'process', 'enabl', 'machin', 'understand', 'human', 'languag', '.']
# Lemmatized Tokens: ['Natural', 'Language', 'Processing', 'enables', 'machine', 'understand', 'human', 'language', '.']
